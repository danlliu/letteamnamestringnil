# %%
import json
from os import path
import GameData as gd
import CharacterData as cd
import Engine
from pprint import pprint

# %%
Engine.run_engine()
# Out:
# [['attacks_Battleaxe', 'attacks_Blowgun', 'attacks_Chain Mail', 'attacks_Dagger', 'attacks_Detect Magic', 'attacks_Eldritch Blast', 'attacks_Fire Bolt', 'attacks_Flame Tongue', 'attacks_Greataxe', 'attacks_Greatclub', 'attacks_Greatsword', 'attacks_Guiding Bolt', 'attacks_Hand Crossbow', 'attacks_Handaxe', 'attacks_Heavy Crossbow', 'attacks_Javelins', 'attacks_Light Crossbow', 'attacks_Light Hammer', 'attacks_Longbow', 'attacks_Longsword', 'attacks_Mace', 'attacks_Maul', 'attacks_Morningstar', 'attacks_Produce Flame', 'attacks_Quarterstaff', 'attacks_Rapier', 'attacks_Scimitar', 'attacks_Shield', 'attacks_Shortbow', 'attacks_Shortsword', 'attacks_Sickle', 'attacks_Sling', 'attacks_Spear', 'attacks_Staff', 'attacks_Trident', 'attacks_Warhammer', 'attacks_Whip'], ['features_Abyssal Resistance', 'features_Action Surge', 'features_Age', 'features_Agonizing Blast', 'features_Allerta', 'features_Apothecary Level Potions', "features_Apothecary's Remedy", 'features_Arcane Recovery', 'feature
# ...
